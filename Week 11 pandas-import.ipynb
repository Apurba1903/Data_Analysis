# %%
import pandas as pd

# %%
# To remove a column || By default it will import first Sheet

pd.read_excel('output.xlsx', index_col='Unnamed: 0')
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
# If I want to import the 2nd Sheet in excel file

pd.read_excel('output.xlsx', sheet_name='Sheet_name_2')
# Out:
#             batsman  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# 0    A Ashish Reddy                 45.0              NaN              36.0
# 1        A Chandila                  NaN              0.0               NaN
# 2          A Chopra                  NaN             35.0              13.0
# 3       A Choudhary                  NaN              NaN               NaN
# 4        A Flintoff                  NaN              NaN              16.0
# ..              ...                  ...              ...               ...
# 456     YV Takawale                 19.0              5.0              14.0
# 457   Yashpal Singh                  NaN              NaN              13.0
# 458     Younis Khan                  NaN              NaN               NaN
# 459    Yuvraj Singh                321.0            118.0             433.0
# 460          Z Khan                 39.0              4.0               4.0
#
# ...

# %% [markdown]
# ### Reading text files

# %%
import pandas as pd

# %% [markdown]
# ##### Have to check how the text file is separated.

# %%
pd.read_csv('something.text', sep='\t')
